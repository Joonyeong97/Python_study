# %%
import pandas as pd
lines= pd.read_csv('제주말.txt', sep='\t',encoding='utf-8',names=['제주어']) # ,names=['제주어','표준어']
len(lines)
# Out:
# 154

# %%
lines
# Out:
#                                 제주어
# 0                      고찌 글라 고찌 가게
# 1                 느영 고찌 글민 지꺼짐이 열배여
# 2                      고찌 글라 고찌 가게
# 3                 느영 고찌 글민 지꺼짐이 백배여
# 4              영도 곱닥헌 날 공기 좋고 사람 좋고
# ..                              ...
# 149                성게도 지깍 구젱기영 전복이영
# 150            아고 이건 뭐라 물꾸럭도 잡앙 와신게
# 151               아고 삼촌 물꾸럭 나 얼마마씸?
# 152              아고 조케야 느랑 기냥 거정가불라
# 153  에고 무신 소리꽈 게민 조냑에랑 당근파당 거정안내주마씀
#
# [154 rows x 1 columns]

# %%
import pandas as pd
lines2= pd.read_csv('표준말.txt', sep='\t',encoding='utf-8',names=['표준어']) # ,names=['제주어','표준어']
len(lines)
# Out:
# 154

# %%
lines2
# Out:
#                             표준어
# 0                   같이 가요 함께 해요
# 1             너와 함께 하면 즐거움이 열배야
# 2                   같이 가요 함께 해요
# 3             너와 함께 하면 즐거움이 백배야
# 4          이렇게 예쁜 날 공기 좋고 사람 좋고
# ..                          ...
# 149             성게도 가득 전복이랑 소라랑
# 150         아고 이건 뭐지 문어도 잡아 왔네요
# 151           아고 삼촌 문어 한마리 얼마죠?
# 152           아고 조카야 너는 그냥 가져가라
# 153  에고 무슨 말씀을 그럼 저녁에 당근파다 드릴게요
#
# [154 rows x 1 columns]

# %%
hap = pd.concat([lines,lines2],axis=1)

# %%
hap.to_csv('jeju1.txt',sep='\t',encoding='utf-8',header=False,index=False)

# %%
import pandas as pd
jeju= pd.read_csv('jeju.txt', sep='\t',encoding='utf-8',names=['제주어','표준어']) # ,names=['제주어','표준어']
len(lines)
# Out:
# 154

# %%
hap = pd.concat([jeju,hap],axis=0)

# %%
hap.to_csv('jeju12.txt',sep='\t',encoding='utf-8',header=False,index=False)

# %%
lines.to_csv('jeju.txt',sep='\t',encoding='utf-8',header=False,index=False)

# %%
with open(data_path, 'r', encoding='utf-16') as f:
    lines = f.read().split('\n')

# %%
target_texts
# Out:
# ['\t가.\n',
#  '\t안녕.\n',
#  '\t뛰어!\n',
#  '\t뛰어.\n',
#  '\t누구?\n',
#  '\t우와!\n',
#  '\t쏴!\n',
#  '\t도와줘!\n',
#  '\t점프!\n',
#  '\t점프해.\n',
#  '\t기다려!\n',
#  '\t잠깐!\n',
#  '\t기다려.\n',
#  '\t시작해.\n',
#  '\t안녕!\n',
#  '\t알았어.\n',
#  '\t시도해볼게.\n',
#  '\t내가 이겼어!\n',
#  '\t아니 이런!\n',
#  '\t진정해.\n',
#  '\t쏴!\n',
#  '\t웃어.\n',
#  '\t공격!\n',
#  '\t공격해!\n',
#  '\t꼼짝마!\n',
#  '\t일어나.\n',
#  '\t알겠어!\n',
#  '\t안아줘.\n',
#  '\t알아.\n',
#  '\t나 일해.\n',
#  '\t들어.\n',
#  '\t절대 아니야.\n',
#  '\t그럴리가!\n',
#  '\t고마워.\n',
#  '\t우리는 시도할거야.\n',
#  '\t우리가 이겼어.\n',
#  '\t왜 나야?\n',
#  '\t굉장해!\n',
#  '\t공정하게 해.\n',
#  '\t저리 가.\n',
#  '\t우리한테 연락해.\n',
#  '\t들어와.\n',
#  '\t어서!\n',
#  '\t나가.\n',
#  '\t저리 가!\n',
#  '\t저리 가.\n',
#  '\t안녕!\n',
#  '\t그가 왔어.\n',
#  '\t그 사람이 왔어.\n',
#  '\t도와줘!\n',
#  '\t도와줘.\n',
#  '\t톰을 때려.\n',
#  '\t동의해.\n',
#  '\t슬퍼.\n',
#  '\t나도.\n',
#  '\t열어.\n',
#  '\t완벽해!\n',
#  '\t보여줘.\n',
#  '\t시끄러워!\n',
#  '\t건너뛰어.\n',
#  '\t그만해.\n',
#  '\t말해.\n',
#  '\t톰이 이겼어.\n',
#  '\t일어나!\n',
#  '\t설거지 해.\n',
# ...
