# %%
from matplotlib import font_manager, rc
font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family =font_name)


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mandarin_cultivated=pd.read_csv('C:/Users/ICT01_10/Documents/Gina/1-project/ppt/지영 _감귤 생산량/mandarin_cultivated.csv', encoding='CP949')
mandarin_cultivated.info() # 문자열 바꾸기 귀찮아서 ㅋㅋㅋㅋㅋ

mandarin_cultivated.columns=["연도", "성과수면적"]
mandarin_cultivated
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
# index    27 non-null int64
# 1        27 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 560.0 bytes
#       연도       성과수면적
# 0   1993  17808.0000
# 1   1994  17944.0000
# 2   1995  19460.0000
# 3   1996  21838.0000
# 4   1997  22366.0000
# 5   1998  22808.0000
# 6   1999  23311.0000
# 7   2000  23705.0000
# 8   2001  23565.0000
# 9   2002  23314.0000
# 10  2003  21635.0000
# 11  2004  19214.0000
# 12  2005  18642.0000
# 13  2006  18289.0000
# 14  2007  18223.0000
# 15  2008  17889.0000
# 16  2009  17901.0000
# 17  2010  17573.0000
# 18  2011  17378.0000
# 19  2012  17146.0000
# 20  2013  16993.0000
# 21  2014  16439.0000
# 22  2015  16112.0000
# 23  2016  17049.0000
# 24  2017  16630.6223
# 25  2018  16029.7769
# 26  2019  15386.0820

# %%
mandarin =pd.read_csv("C:/Users/ICT01_10/Documents/Gina/1-project/ppt/지영 _감귤 생산량/2018 statisitic.csv", 
                        encoding='UTF-8')
mandarin["생산량 톤"]=mandarin.iloc[:,2]*1000
mandarin["단수 kg/10a 기준"]=mandarin["생산량 톤"]/mandarin["재배면적"] *100
result=mandarin.copy()
result=result.iloc[8:,]
result=result.reset_index()
result.drop(labels="index", axis=1, inplace=True)
result
# Out:
#       연도   재배면적  생산량 천t    증감률   생산량 톤  단수 kg/10a 기준
# 0   1993  21727     619 -0.139  619000   2848.989736
# 1   1994  21500     548 -0.113  548000   2548.837209
# 2   1995  23662     615  0.120  615000   2599.104049
# 3   1996  25820     480 -0.219  480000   1859.024012
# 4   1997  25860     693  1.444  693000   2679.814385
# 5   1998  25870     544 -0.215  544000   2102.821801
# 6   1999  25781     639  0.175  639000   2478.569489
# 7   2000  26813     563 -0.119  563000   2099.727744
# 8   2001  26650     645  0.146  645000   2420.262664
# 9   2002  26234     643 -0.003  643000   2451.017763
# 10  2003  24560     632 -0.017  632000   2573.289902
# 11  2004  22048     584 -0.076  584000   2648.766328
# 12  2005  21430     638  0.092  638000   2977.134858
# 13  2006  21382     620 -0.028  620000   2899.635207
# 14  2007  21463     778  0.255  778000   3624.842753
# 15  2008  21201     636 -0.183  636000   2999.858497
# 16  2009  21354     727  0.143  727000   3404.514377
# 17  2010  21122     615 -0.154  615000   2911.656093
# 18  2011  21363     645  0.049  645000   3019.238871
# 19  2012  21324     654  0.014  654000   3066.966798
# 20  2013  21308     655  0.002  655000   3073.962831
# 21  2014  21312     688  0.050  688000   3228.228228
# 22  2015  21241     640 -0.070  640000   3013.040817
# 23  2016  21672     610 -0.047  610000   2814.691768
# 24  2017  21486     597 -0.021  597000   2778.553477
# 25  2018  21458     621  0.040  621000   2894.025538

# %%
dataset=pd.merge(result,mandarin_cultivated)
dataset["성과수비율"]=dataset.iloc[:,6]/dataset.iloc[:,1]
dataset
# Out:
#           dansu  agingCultivatedArea  agingRate
# 0   2848.989736           17808.0000   0.819625
# 1   2548.837209           17944.0000   0.834605
# 2   2599.104049           19460.0000   0.822416
# 3   1859.024012           21838.0000   0.845778
# 4   2679.814385           22366.0000   0.864888
# 5   2102.821801           22808.0000   0.881639
# 6   2478.569489           23311.0000   0.904193
# 7   2099.727744           23705.0000   0.884086
# 8   2420.262664           23565.0000   0.884240
# 9   2451.017763           23314.0000   0.888694
# 10  2573.289902           21635.0000   0.880904
# 11  2648.766328           19214.0000   0.871462
# 12  2977.134858           18642.0000   0.869902
# 13  2899.635207           18289.0000   0.855346
# 14  3624.842753           18223.0000   0.849043
# 15  2999.858497           17889.0000   0.843781
# 16  3404.514377           17901.0000   0.838297
# 17  2911.656093           17573.0000   0.831976
# 18  3019.238871           17378.0000   0.813463
# 19  3066.966798           17146.0000   0.804071
# 20  3073.962831           16993.0000   0.797494
# 21  3228.228228           16439.0000   0.771349
# 22  3013.040817           16112.0000   0.758533
# 23  2814.691768           17049.0000   0.786683
# 24  2778.553477           16630.6223   0.774021
# 25  2894.025538           16029.7769   0.747030

# %%
mandarin.dataset=dataset[["year",'productionT','agingRate']]#, "cultivatedArea",'agingCultivatedArea',"agingRate"
mandarin.dataset
# Out:
# C:\Users\ICT01_10\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.
#     year  productionT  agingRate
# 0   1993       619000   0.819625
# 1   1994       548000   0.834605
# 2   1995       615000   0.822416
# 3   1996       480000   0.845778
# 4   1997       693000   0.864888
# 5   1998       544000   0.881639
# 6   1999       639000   0.904193
# 7   2000       563000   0.884086
# 8   2001       645000   0.884240
# 9   2002       643000   0.888694
# 10  2003       632000   0.880904
# 11  2004       584000   0.871462
# 12  2005       638000   0.869902
# 13  2006       620000   0.855346
# 14  2007       778000   0.849043
# 15  2008       636000   0.843781
# 16  2009       727000   0.838297
# 17  2010       615000   0.831976
# 18  2011       645000   0.813463
# 19  2012       654000   0.804071
# 20  2013       655000   0.797494
# 21  2014       688000   0.771349
# 22  2015       640000   0.758533
# 23  2016       610000   0.786683
# 24  2017       597000   0.774021
# 25  2018       621000   0.747030

# %%
weatherBloom =pd.read_csv("C:/Users/ICT01_10/Documents/Gina/1-project/j4,5.csv", 
                        encoding='CP949')

weatherBloom.columns=['Bloom', 'TempOfBloom', 'PrecipitationOfBloom', 'InsolationOfBloom', 
                     'HumidityOfBloom', 'WindspeedOfBloom','PHUOfBloom']
weatherBloom.drop(labels="Bloom", axis=1, inplace=True)
weatherBloom.drop(labels="TempOfBloom",axis=1, inplace=True)

# %%
weatherHarvest =pd.read_csv("C:/Users/ICT01_10/Documents/Gina/1-project/j7,8,9.csv", 
                        encoding='CP949')


weatherHarvest.columns=['Harvest', 'TempOfHarvest', 'PrecipitationOfHarvest', 'InsolationOfHarvest', 
                     'HumidityOfHarvest', 'WindspeedOfHarvest','PHUOfHarvest']

weatherHarvest.drop(labels="Harvest", axis=1, inplace=True)

weatherHarvest.drop(labels="TempOfHarvest",axis=1, inplace=True)

# %%
weather=pd.merge(weatherBloom,weatherHarvest, left_index=True, right_index=True)
weather
# Out:
#     PrecipitationOfBloom  InsolationOfBloom  HumidityOfBloom  \
# 0                 158.30            489.345             78.5
# 1                 224.40            473.190             83.5
# 2                 256.30            533.630             76.0
# 3                 152.70            532.375             73.0
# 4                 200.85            508.275             74.0
# 5                 193.85            456.845             88.0
# 6                 189.80            586.580             80.5
# 7                 111.35            622.505             75.0
# 8                 182.75            597.355             75.0
# 9                 189.50            488.165             79.0
# 10                308.50            504.225             79.5
# 11                339.15            521.545             77.5
# 12                136.60            637.320             73.0
# 13                268.15            512.640             78.0
# 14                117.95            595.825             72.0
# 15                160.55            591.210             71.0
# 16                143.30            658.400             69.0
# 17                217.35            577.125             70.5
# 18                136.90            630.770             77.0
# 19                330.25            639.280             78.0
# 20                146.65            665.700             76.5
# 21                237.10            608.945             76.5
# 22                358.60            559.005             81.0
# 23                255.50            537.495             83.0
# 24                144.45            613.935             80.0
# 25                334.05            546.625             85.0
#
#     WindspeedOfBloom  PHUOfBloom  PrecipitationOfHarvest  InsolationOfHarvest  \
# 0               6.80      19.180              365.066667           389.383333
# 1               6.30      21.900              216.633333           644.433333
# 2               6.35      18.320              419.733333           511.973333
# 3               6.00      18.440              156.733333           461.880000
# 4               6.90      21.380              183.700000           464.466667
# 5               5.30      23.400              368.133333           561.200000
# 6               7.15      21.160              697.500000           403.056667
# 7               6.50      19.900              247.233333           573.126667
# 8               5.45      21.800              245.066667           600.323333
# 9               6.35      22.064              370.700000           514.210000
# 10              6.55      22.604              384.300000           473.493333
# 11              7.25      21.434              341.666667           563.243333
# 12              6.10      21.326              231.333333           522.813333
# 13              7.15      19.940              291.500000           510.210000
# 14              6.25      21.560              636.000000           549.250000
# 15              5.65      21.074              278.700000           572.780000
# 16              6.20      21.524              244.100000           565.476667
# 17              6.30      18.595              328.533333           568.070000
# 18              6.10      20.350              221.900000           606.486667
# 19              5.50      22.420              544.366667           580.636667
# 20              6.25      20.570              110.466667           612.640000
# 21              5.55      22.240              389.600000           433.180000
# 22              5.50      21.700              313.500000           539.516667
# 23              5.45      22.680              216.733333           536.323333
# 24              5.35      22.960              322.533333           550.143333
# 25              4.95      23.000              315.666667           546.823333
#
#     HumidityOfHarvest  WindspeedOfHarvest  PHUOfHarvest
# 0           84.666667            5.600000        34.140
# 1           82.666667            6.100000        39.030
# 2           84.000000            5.466667        37.351
# 3           82.666667            4.766667        37.378
# 4           82.666667            6.366667        37.000
# 5           86.333333            5.966667        39.340
# 6           89.333333            5.733333        36.370
# 7           82.666667            5.766667        38.170
# 8           77.666667            5.533333        38.400
# 9           86.666667            5.733333        36.208
# 10          87.666667            5.400000        37.747
# 11          83.333333            5.800000        39.130
# 12          85.333333            5.333333        38.990
# 13          82.333333            5.233333        37.360
# 14          83.000000            5.200000        38.435
# 15          80.333333            4.633333        38.530
# 16          77.000000            4.766667        36.847
# 17          84.666667            5.200000        39.520
# 18          83.000000            5.266667        38.280
# 19          92.000000            5.100000        38.040
# 20          83.000000            5.166667        40.470
# 21          87.000000            5.000000        36.480
# 22          85.333333            4.600000        36.390
# 23          85.666667            4.566667        39.214
# 24          86.000000            5.066667        40.470
# 25          90.000000            5.333333        39.480

# %%
mandarinDataset=pd.merge(mandarin.dataset, weather, left_index=True, right_index=True)
mandarinDataset.index=mandarinDataset['year']
mandarinDataset.drop(labels='year', axis=1, inplace=True)
# 2007           549.250000          83.000000            5.200000        38.435
# 2008           572.780000          80.333333            4.633333        38.530
# 2009           565.476667          77.000000            4.766667        36.847
# 2010           568.070000          84.666667            5.200000        39.520
# 2011           606.486667          83.000000            5.266667        38.280
# 2012           580.636667          92.000000            5.100000        38.040
# 2013           612.640000          83.000000            5.166667        40.470
# 2014           433.180000          87.000000            5.000000        36.480
# 2015           539.516667          85.333333            4.600000        36.390
# 2016           536.323333          85.666667            4.566667        39.214
# 2017           550.143333          86.000000            5.066667        40.470
# 2018           546.823333          90.000000            5.333333        39.480

# %%
mandarinDataset.describe()
# Out:
#          productionT  agingRate  PrecipitationOfBloom  InsolationOfBloom  \
# count      26.000000  26.000000             26.000000          26.000000
# mean   628038.461538   0.835520            211.340385         564.935000
# std     58691.383197   0.043798             74.530217          60.445129
# min    480000.000000   0.747030            111.350000         456.845000
# 25%    611250.000000   0.806419            148.162500         514.866250
# 50%    634000.000000   0.841039            191.825000         568.065000
# 75%    645000.000000   0.871072            256.100000         612.687500
# max    778000.000000   0.904193            358.600000         665.700000
#
#        HumidityOfBloom  WindspeedOfBloom  PHUOfBloom  PrecipitationOfHarvest  \
# count        26.000000         26.000000   26.000000               26.000000
# mean         77.307692          6.123077   21.212346              324.669231
# std           4.606684          0.628368    1.432233              136.491748
# min          69.000000          4.950000   18.320000              110.466667
# 25%          74.250000          5.512500   20.405000              234.525000
# 50%          77.250000          6.225000   21.479000              314.583333
# 75%          79.875000          6.462500   22.196000              370.058333
# max          88.000000          7.250000   23.400000              697.500000
#
#        InsolationOfHarvest  HumidityOfHarvest  WindspeedOfHarvest  \
# count            26.000000          26.000000           26.000000
# mean            532.890000          84.423077            5.334615
# std              63.605209           3.381726            0.468518
# min             389.383333          77.000000            4.566667
# 25%             510.650833          82.666667            5.075000
# 50%             548.036667          84.333333            5.300000
# 75%             571.602500          86.250000            5.700000
# max             644.433333          92.000000            6.366667
#
#        PHUOfHarvest
# count     26.000000
# mean      38.029615
# std        1.459966
# min       34.140000
# 25%       37.087750
# 50%       38.225000
# 75%       39.105000
# max       40.470000

# %%
mandarinDataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 1993 to 2018
# Data columns (total 12 columns):
# productionT               26 non-null int64
# agingRate                 26 non-null float64
# PrecipitationOfBloom      26 non-null float64
# InsolationOfBloom         26 non-null float64
# HumidityOfBloom           26 non-null float64
# WindspeedOfBloom          26 non-null float64
# PHUOfBloom                26 non-null float64
# PrecipitationOfHarvest    26 non-null float64
# InsolationOfHarvest       26 non-null float64
# HumidityOfHarvest         26 non-null float64
# WindspeedOfHarvest        26 non-null float64
# PHUOfHarvest              26 non-null float64
# dtypes: float64(11), int64(1)
# memory usage: 2.6 KB

# %%
mandarinDataset.hist(bins=50, figsize=(20,15))
plt.show()

# %%
from pandas.plotting import scatter_matrix
#attributes=["agingRate","PrecipitationOfBloom","HumidityOfHarvest","WindspeedOfBloom","PHUOfBloom","PrecipitationOfHarvest","HumidityOfHarvest","WindspeedOfHarvest","PHUOfHarvest"]
scatter_matrix(mandarinDataset, figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30B33D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CFCC408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2DBCA488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F5DA288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31151B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CF1BF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31BF4888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31912908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F59A088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B319DD808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CED0448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F4DB548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31BBCD48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31D8F148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CE96448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D5F3BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F74F6C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2DB1D408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F59E908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F4E6C48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31DE8F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F6736C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31F17188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F557548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F488A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31B77988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CE5F108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CFAFD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F4A2AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F420C48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F45A248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F6ADEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2DA8D448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31F24888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2E2F43C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2E31D8C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CF8C048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D008508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31DA8F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CFE9488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D97E808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2E348E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31A1C6C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F45F508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31D814C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B316155C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F3CA6C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CE85788>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D62D888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31BC3988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2E307A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F5BBBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CEDFCC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31AD9D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CDF4EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2F48BFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2CDB9108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31ABC248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31B84248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31B283C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31C7B508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B33000608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31C28708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2DAC9508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B3193A608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31A80708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31CB5848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31A36948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31EC8A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B319B0B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2DAAAC48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B3349FD48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B33476E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B32FC1F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B32F9BE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31BEC148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31F01288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B33406388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2DA21488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D9E0588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31001E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B319E6788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31F8C8C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30EA79C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30EBFA88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30D09BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30DDFCC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B318E0DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30D82F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31CF3F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B316600C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30DF2208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31033308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31D2E408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B310734C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30F21608>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30FA6708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31974808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30F44948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B310B5A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D417AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30E32B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30E4ED08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2C983E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B334EDF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D119FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D156108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D18E248>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D1C5348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D1FF448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D237548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D276E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D2AB748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D2E5888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D31D988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B2D354A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B3070EB88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30746CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B3077FDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B307B8EC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B307EEF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B3082E088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30865188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B3089F2C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B308D73C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B3090F488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B309495C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B309826C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B309BA7C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B309F2908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30A2DA08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30A65A88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30A9EBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30AD6CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B30FCEDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31687F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B316BDF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B316FC0C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31735208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B3176E308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B317A8408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B317DF448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31819548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022B31856E48>]],
#       dtype=object)

# %%
# 변수들끼리 상관관계를 분석해봅시다
y = mandarinDataset.iloc[:,1]
X = mandarinDataset.iloc[:,1:]


# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,15))
sns.heatmap(data=X.corr(), annot=True, fmt='.2f', linewidths=.5, cmap='hot_r')
# Out:
# C:\Users\ICT01_10\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ICT01_10\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
y = mandarinDataset.iloc[:,0]
X = mandarinDataset.iloc[:,0:]
mandarinDataset.drop(labels="InsolationOfHarvest", axis=1, inplace=True)

#다중공선성이 있는 수확기의 일조량은 제외 = 착색에 영향이므로 이미 수확과.

# %%
y=mandarinDataset.iloc[:,-1]
X=mandarinDataset.iloc[:,1:]

plt.figure(figsize=(15,15))
sns.heatmap(data=X.corr(), annot=True, fmt='.3f', linewidths=.5, cmap='hot_r')
# Out:
# C:\Users\ICT01_10\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ICT01_10\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 분산이 작은 데이터 == 가장 영향력 없는 변수 > noise 제거 noise elimination)
# 5개 변수에 대해서 스텝 1개씩. = 10개 변수중에서 5개만 남기겠다.

# %%
from sklearn.feature_selection import RFE 
from sklearn.svm import SVR 

estimator =SVR(kernel='linear') #선형회귀Regression 예측 
selector =RFE(estimator, 5, step=1) 


# RFE(): ( 기존의 추정기를 받고 , 변수추출갯수(제거후), step 지정 )
selector = selector.fit(X, y)
selector.support_
# Out:
# array([False, False, False, False,  True,  True, False,  True,  True,
#         True])

# %%
selector.ranking_
# Out:
# array([2, 6, 5, 3, 1, 1, 4, 1, 1, 1])

# %%
selector.n_features_ # 잡음제거한 변수 5개 남김.
# Out:
# 5

# %%
selector.estimator_ # 변수를 제거한 추정기.
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# # PCA 모델 입력 전단계 = 특징추출하기 = noise 제거

# %%
# PHU 에 상관관계가 큰 개화기 수확기 평균기온 제거 및, 다중공선성이 보였던, 수확기 일조량 제거된 데이터셋
mandarin_extraction=mandarinDataset[["productionT","agingRate","HumidityOfHarvest","WindspeedOfBloom","PHUOfBloom","PrecipitationOfHarvest","HumidityOfHarvest","WindspeedOfHarvest","PHUOfHarvest"]]
mandarin_extraction
# Out:
#       productionT  agingRate  HumidityOfHarvest  WindspeedOfBloom  PHUOfBloom  \
# year
# 1993       619000   0.819625          84.666667              6.80      19.180
# 1994       548000   0.834605          82.666667              6.30      21.900
# 1995       615000   0.822416          84.000000              6.35      18.320
# 1996       480000   0.845778          82.666667              6.00      18.440
# 1997       693000   0.864888          82.666667              6.90      21.380
# 1998       544000   0.881639          86.333333              5.30      23.400
# 1999       639000   0.904193          89.333333              7.15      21.160
# 2000       563000   0.884086          82.666667              6.50      19.900
# 2001       645000   0.884240          77.666667              5.45      21.800
# 2002       643000   0.888694          86.666667              6.35      22.064
# 2003       632000   0.880904          87.666667              6.55      22.604
# 2004       584000   0.871462          83.333333              7.25      21.434
# 2005       638000   0.869902          85.333333              6.10      21.326
# 2006       620000   0.855346          82.333333              7.15      19.940
# 2007       778000   0.849043          83.000000              6.25      21.560
# 2008       636000   0.843781          80.333333              5.65      21.074
# 2009       727000   0.838297          77.000000              6.20      21.524
# 2010       615000   0.831976          84.666667              6.30      18.595
# 2011       645000   0.813463          83.000000              6.10      20.350
# 2012       654000   0.804071          92.000000              5.50      22.420
# 2013       655000   0.797494          83.000000              6.25      20.570
# 2014       688000   0.771349          87.000000              5.55      22.240
# 2015       640000   0.758533          85.333333              5.50      21.700
# 2016       610000   0.786683          85.666667              5.45      22.680
# 2017       597000   0.774021          86.000000              5.35      22.960
# 2018       621000   0.747030          90.000000              4.95      23.000
#
#       PrecipitationOfHarvest  HumidityOfHarvest  WindspeedOfHarvest  \
# year
# 1993              365.066667          84.666667            5.600000
# 1994              216.633333          82.666667            6.100000
# 1995              419.733333          84.000000            5.466667
# 1996              156.733333          82.666667            4.766667
# 1997              183.700000          82.666667            6.366667
# 1998              368.133333          86.333333            5.966667
# 1999              697.500000          89.333333            5.733333
# 2000              247.233333          82.666667            5.766667
# 2001              245.066667          77.666667            5.533333
# 2002              370.700000          86.666667            5.733333
# 2003              384.300000          87.666667            5.400000
# 2004              341.666667          83.333333            5.800000
# 2005              231.333333          85.333333            5.333333
# 2006              291.500000          82.333333            5.233333
# 2007              636.000000          83.000000            5.200000
# 2008              278.700000          80.333333            4.633333
# 2009              244.100000          77.000000            4.766667
# 2010              328.533333          84.666667            5.200000
# 2011              221.900000          83.000000            5.266667
# 2012              544.366667          92.000000            5.100000
# 2013              110.466667          83.000000            5.166667
# 2014              389.600000          87.000000            5.000000
# 2015              313.500000          85.333333            4.600000
# 2016              216.733333          85.666667            4.566667
# 2017              322.533333          86.000000            5.066667
# 2018              315.666667          90.000000            5.333333
#
#       PHUOfHarvest
# year
# 1993        34.140
# 1994        39.030
# 1995        37.351
# 1996        37.378
# 1997        37.000
# 1998        39.340
# 1999        36.370
# 2000        38.170
# 2001        38.400
# 2002        36.208
# 2003        37.747
# 2004        39.130
# 2005        38.990
# 2006        37.360
# 2007        38.435
# 2008        38.530
# 2009        36.847
# 2010        39.520
# 2011        38.280
# 2012        38.040
# 2013        40.470
# 2014        36.480
# 2015        36.390
# 2016        39.214
# 2017        40.470
# 2018        39.480

# %%
# 정규화 4가지 버젼 다 해보쟝
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale, StandardScaler

y=mandarin_extraction.iloc[:,0]
X=mandarin_extraction.iloc[:,1:]

scale_X = scale(X)
robust_X = robust_scale(X)
minmax_X = minmax_scale(X)
maxabs_X = maxabs_scale(X)

scaler = StandardScaler() # 표준정규분포기에 데이터 넣기위해 인스턴스
stdScale_X = scaler.fit(X)
std_transformed_X = scaler.transform(X)
X.std(), std_transformed_X.std()
# Out:
# (WindspeedOfBloom      0.628368
#  PHUOfBloom            1.432233
#  HumidityOfHarvest     3.381726
#  WindspeedOfHarvest    0.468518
#  PHUOfHarvest          1.459966
#  dtype: float64, 1.0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scale_X, y, random_state=0)


# 최소자승법을 해봅시다!
import statsmodels.api as sm
result = sm.OLS(y_train, X_train).fit()
result.summary()

# R-squared => 설명력 : 회귀제곱합/ 총오차제곱합 0.001
# Adj. R-squared 모델을 통해 수정된 값을 쓴다 -0.054  정규분포로 안바꿔주니 못쓰는값...
# Out:
# C:\Users\ICT01_10\Anaconda3\lib\site-packages\scipy\stats\stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            productionT   R-squared (uncentered):                   0.124
# Model:                            OLS   Adj. R-squared (uncentered):             -0.188
# Method:                 Least Squares   F-statistic:                             0.3977
# Date:                Tue, 21 Jan 2020   Prob (F-statistic):                       0.842
# Time:                        18:39:49   Log-Likelihood:                         -279.37
# No. Observations:                  19   AIC:                                      568.7
# Df Residuals:                      14   BIC:                                      573.5
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1         -5.188e+04   2.53e+05     -0.205      0.840   -5.95e+05    4.91e+05
# x2          2.331e+05   2.39e+05      0.976      0.346   -2.79e+05    7.45e+05
# x3         -6.358e+04   1.52e+05     -0.419      0.681   -3.89e+05    2.62e+05
# x4         -1.764e+04   1.92e+05     -0.092      0.928    -4.3e+05    3.95e+05
# x5         -2.456e+05   2.04e+05     -1.203      0.249   -6.83e+05    1.92e+05
# ==============================================================================
# Omnibus:                        1.338   Durbin-Watson:                   0.189
# Prob(Omnibus):                  0.512   Jarque-Bera (JB):                0.923
# Skew:                          -0.206   Prob(JB):                        0.630
# Kurtosis:                       2.002   Cond. No.                         3.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(robust_X, y, random_state=0)



import statsmodels.api as sm
result = sm.OLS(y_train, X_train).fit()
result.summary()


# R-squared => 설명력 : 회귀제곱합/ 총오차제곱합 0.001  =>0.021
# Adj. R-squared 모델을 통해 수정된 값을 쓴다 -0.054  robust 정규분포로 =>-0.034
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            productionT   R-squared (uncentered):                   0.311
# Model:                            OLS   Adj. R-squared (uncentered):              0.064
# Method:                 Least Squares   F-statistic:                              1.262
# Date:                Tue, 21 Jan 2020   Prob (F-statistic):                       0.334
# Time:                        18:39:51   Log-Likelihood:                         -277.10
# No. Observations:                  19   AIC:                                      564.2
# Df Residuals:                      14   BIC:                                      568.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1         -6.135e+05   3.03e+05     -2.023      0.063   -1.26e+06    3.69e+04
# x2         -8.493e+04   2.72e+05     -0.312      0.760   -6.69e+05    4.99e+05
# x3         -1.536e+04   1.46e+05     -0.105      0.918   -3.28e+05    2.98e+05
# x4          2.234e+05   2.24e+05      0.999      0.335   -2.56e+05    7.03e+05
# x5         -4.628e+05   2.41e+05     -1.924      0.075   -9.79e+05    5.31e+04
# ==============================================================================
# Omnibus:                        0.727   Durbin-Watson:                   0.524
# Prob(Omnibus):                  0.695   Jarque-Bera (JB):                0.748
# Skew:                          -0.310   Prob(JB):                        0.688
# Kurtosis:                       2.252   Cond. No.                         3.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(minmax_X , y, random_state=0)


# 최소자승법을 해봅시다!
import statsmodels.api as sm
result = sm.OLS(y_train, X_train).fit()
result.summary()


# R-squared => 설명력 : 회귀제곱합/ 총오차제곱합 0.001  =>0.885
# Adj. R-squared 모델을 통해 수정된 값을 쓴다 -0.054   minmax 정규분포로 =>0.878
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            productionT   R-squared (uncentered):                   0.971
# Model:                            OLS   Adj. R-squared (uncentered):              0.961
# Method:                 Least Squares   F-statistic:                              94.56
# Date:                Tue, 21 Jan 2020   Prob (F-statistic):                    2.79e-10
# Time:                        18:39:54   Log-Likelihood:                         -246.92
# No. Observations:                  19   AIC:                                      503.8
# Df Residuals:                      14   BIC:                                      508.6
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          4.998e+05   1.11e+05      4.496      0.001    2.61e+05    7.38e+05
# x2          4.128e+05   1.49e+05      2.777      0.015     9.4e+04    7.32e+05
# x3          3.344e+04   1.21e+05      0.277      0.786   -2.26e+05    2.93e+05
# x4         -1.116e+05   1.35e+05     -0.827      0.422   -4.01e+05    1.78e+05
# x5           2.46e+05   1.27e+05      1.937      0.073   -2.64e+04    5.18e+05
# ==============================================================================
# Omnibus:                        1.687   Durbin-Watson:                   1.768
# Prob(Omnibus):                  0.430   Jarque-Bera (JB):                0.993
# Skew:                          -0.168   Prob(JB):                        0.609
# Kurtosis:                       1.932   Cond. No.                         8.31
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(maxabs_X , y, random_state=0)


# 최소자승법을 해봅시다!
import statsmodels.api as sm
result = sm.OLS(y_train, X_train).fit()
result.summary()


# R-squared => 설명력 : 회귀제곱합/ 총오차제곱합 0.001  =>0.993
# Adj. R-squared 모델을 통해 수정된 값을 쓴다 -0.054   maxabs 정규분포로 =>0.993
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            productionT   R-squared (uncentered):                   0.996
# Model:                            OLS   Adj. R-squared (uncentered):              0.994
# Method:                 Least Squares   F-statistic:                              674.1
# Date:                Tue, 21 Jan 2020   Prob (F-statistic):                    3.67e-16
# Time:                        18:39:56   Log-Likelihood:                         -228.49
# No. Observations:                  19   AIC:                                      467.0
# Df Residuals:                      14   BIC:                                      471.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          3.835e+05   1.56e+05      2.462      0.027    4.95e+04    7.17e+05
# x2          1.033e+06   2.76e+05      3.742      0.002    4.41e+05    1.62e+06
# x3          -2.11e+05   2.62e+05     -0.807      0.433   -7.72e+05     3.5e+05
# x4         -1.624e+05   1.82e+05     -0.891      0.388   -5.54e+05    2.29e+05
# x5         -3.321e+05   2.56e+05     -1.295      0.216   -8.82e+05    2.18e+05
# ==============================================================================
# Omnibus:                        1.308   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.520   Jarque-Bera (JB):                1.120
# Skew:                          -0.432   Prob(JB):                        0.571
# Kurtosis:                       2.182   Cond. No.                         65.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# OLS 말고 선형회귀모델에 바로 넣어서 구해도 됨.
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

production_model = LinearRegression().fit(X, y)
print(production_model.coef_, production_model.intercept_)
# intercept : 절편,  9개의 독립변수의 coefficient계수
# Out:
# [ 30460.40907639  21266.0806767   -3418.47501513 -40424.12437065
#   -9810.7906386 ] 867769.4985526635

# %%
predictions = production_model.predict(X)

plt.scatter(y, predictions)
plt.xlabel("original")
plt.ylabel("prediction")
plt.title("linear Regression")
# Out:
# Text(0.5, 1.0, 'linear Regression')
