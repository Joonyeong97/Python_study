# %%
import requests
from bs4 import BeautifulSoup
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import nltk
from konlpy.tag import Twitter
import numpy as np
from PIL import Image

# %%
res = requests.get('https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=011&aid=0003700330&date=20200225&type=1&rankingSeq=4&rankingSectionId=102')

soup = BeautifulSoup(res.content, 'html.parser')
body = soup.select('._article_body_contents')[0]
text = body.get_text() # for p in body.find_all('div'))
t = Twitter()
tokens_ko = t.nouns(text)
ko = nltk.Text(tokens_ko, name="비상")
ko.vocab().most_common(10)
data = ko.vocab().most_common(1000)
# Out:
# C:\Users\82105\Anaconda3\envs\Testing\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
text
# Out:
# "\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}\n\n\t\n\t[서울경제] [속보] 이명박 전 대통령, 재구속 엿새 만에 다시 석방자동차부품업체 다스의 자금을 횡령하고 삼성으로부터 뇌물을 받은 혐의로 항소심에서 징역 17년 실형을 선고받은 이명박 전 대통령. / 연합뉴스항소심에서 징역 17년을 선고받았던 이명박 전 대통령이 법정에서 재구속된 지 6일 만에 석방된다. 25일 법조계에 따르면 서울고법 형사1부(정준영 송영승 강상욱 부장판사)는 이 전 대통령이 보석 취소 결정에 대해 재항고함에 따라 그 집행을 정지했다. 집행정지 결정에 따라 이 전 대통령은 이날 자정 이전에 서울동부구치소에서 석방된다. 지난 19일 징역 17년을 선고받고 보석이 취소돼 법정에서 구속된 지 엿새 만이다.이명박 전 대통령은 이날 보석 취소 결정에 대해 대법원에 재항고하면서 관련 법령에 따라 보석 취소의 집행정지도 이뤄져야 한다고 주장했다. 항소심 재판부는 이를 받아들였다./강신우기자 seen@sedaily.com[서울경제 바로가기]▶ '한 눈에 쏙' 새로워진 서울경제 모바일 페이지를 만나보세요. GO~▶ 네이버 채널에서 '서울경제' 채널 구독해주세요! 저작권자 ⓒ 서울경제, 무단 전재 및 재배포 금지\n\t\n"

# %%
tokens_ver = t.pos(text)
# Out:
# [('\n\n\n\n\n', 'Foreign'),
#  ('//', 'Punctuation'),
#  ('flash', 'Alpha'),
#  ('오류', 'Noun'),
#  ('를', 'Josa'),
#  ('우회', 'Noun'),
#  ('하기', 'Verb'),
#  ('위', 'Noun'),
#  ('한', 'Josa'),
#  ('함수', 'Noun'),
#  ('추가', 'Noun'),
#  ('\n', 'Foreign'),
#  ('function', 'Alpha'),
#  ('_', 'Punctuation'),
#  ('flash', 'Alpha'),
#  ('_', 'Punctuation'),
#  ('removeCallback', 'Alpha'),
#  ('()', 'Punctuation'),
#  ('{}', 'Punctuation'),
#  ('\n\n\t\n\t', 'Foreign'),
#  ('[', 'Punctuation'),
#  ('서울', 'Noun'),
#  ('경제', 'Noun'),
#  (']', 'Punctuation'),
#  ('[', 'Punctuation'),
#  ('속보', 'Noun'),
#  (']', 'Punctuation'),
#  ('이명박', 'Noun'),
#  ('전', 'Noun'),
#  ('대통령', 'Noun'),
#  (',', 'Punctuation'),
#  ('재', 'Noun'),
#  ('구속', 'Noun'),
#  ('엿새', 'Noun'),
#  ('만에', 'Josa'),
#  ('다시', 'Noun'),
#  ('석방', 'Noun'),
#  ('자동차', 'Noun'),
#  ('부품', 'Noun'),
#  ('업체', 'Noun'),
#  ('다스', 'Noun'),
#  ('의', 'Josa'),
#  ('자금', 'Noun'),
#  ('을', 'Josa'),
#  ('횡령', 'Noun'),
#  ('하고', 'Josa'),
# ...

# %%
tokens_ko
# Out:
# ['오류',
#  '우회',
#  '위',
#  '함수',
#  '추가',
#  '서울',
#  '경제',
#  '속보',
#  '이명박',
#  '전',
#  '대통령',
#  '재',
#  '구속',
#  '엿새',
#  '다시',
#  '석방',
#  '자동차',
#  '부품',
#  '업체',
#  '다스',
#  '자금',
#  '횡령',
#  '삼성',
#  '뇌물',
#  '혐의',
#  '항소심',
#  '징역',
#  '실형',
#  '선고',
#  '이명박',
#  '전',
#  '대통령',
#  '연합뉴스',
#  '항소심',
#  '징역',
#  '선고',
#  '이명박',
#  '전',
#  '대통령',
#  '법정',
#  '재',
#  '구속',
#  '석방',
#  '법조',
#  '서울',
#  '고법',
#  '형사',
#  '부',
#  '정준영',
#  '송영',
#  '승',
#  '강상욱',
#  '부장',
#  '판사',
#  '이',
#  '전',
#  '대통령',
#  '보석',
#  '취소',
#  '결정',
#  '대해',
#  '재항',
#  '고함',
#  '그',
#  '집행',
#  '정지',
#  '집행정지',
#  '결정',
#  '이',
#  '전',
#  '대통령',
#  '날',
#  '자정',
#  '이전',
#  '동부',
#  '구치소',
#  '석방',
#  '지난',
#  '징역',
#  '선고',
#  '보석',
#  '취소',
#  '법정',
#  '구속',
#  '엿새',
#  '만이',
#  '이명박',
#  '전',
#  '대통령',
#  '날',
#  '보석',
#  '취소',
#  '결정',
#  '대해',
#  '대법원',
#  '재',
#  '항고',
#  '관련',
#  '법령',
#  '보석',
#  '취소',
#  '집행정지',
#  '주장',
#  '항소심',
#  '재판',
#  '강신우',
#  '기자',
#  '서울',
#  '경제',
#  '바로가기',
# ...
